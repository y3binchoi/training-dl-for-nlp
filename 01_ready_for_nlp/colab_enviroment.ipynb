# %% [markdown]
# # colab 환경 구성

# %% [markdown]
# > 참고 : https://opentutorials.org/module/3653/22012

# %% [markdown]
# ### GPU 사용중인지 체크

# %%
import tensorflow as tf

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### CPU 사용중인지 체크

# %%
from tensorflow.python.client import device_lib

# %%
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10364002727201071138
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14415560704
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12258391905892728720
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %% [markdown]
# ### Colab은 Docker위의 Virtual Machine으로 동작한다. 리눅스 기반이고, 따라서 느낌표(!) 표시 뒤에 리눅스 명령어를 붙이면 동작한다.

# %% [markdown]
# 메모리 사양 확인

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13297220 kB
# MemFree:         9582248 kB
# MemAvailable:   11797524 kB
# Buffers:           68032 kB
# Cached:          2114768 kB
# SwapCached:            0 kB
# Active:           504620 kB
# Inactive:        2873652 kB
# Active(anon):        892 kB
# Inactive(anon):   960936 kB
# Active(file):     503728 kB
# Inactive(file):  1912716 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               644 kB
# Writeback:             0 kB
# AnonPages:       1195532 kB
# Mapped:           660256 kB
# Shmem:             11420 kB
# KReclaimable:      80820 kB
# Slab:             120676 kB
# SReclaimable:      80820 kB
# SUnreclaim:        39856 kB
# KernelStack:        4512 kB
# PageTables:        13080 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6648608 kB
# Committed_AS:    3363932 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# CPU 사양 확인

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.194
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %% [markdown]
# 폴더트리 확인

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 .
# drwxr-xr-x 1 root root 4096 Dec 24 13:30 ..
# drwxr-xr-x 4 root root 4096 Dec 20 20:18 .config
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 sample_data

# %% [markdown]
# 내장함수 사용법 확인

# %%
print?
